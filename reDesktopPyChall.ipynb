# %%
import pickle as peakhell
import urllib as ul

# %%
x = ul.urlopen("http://www.pythonchallenge.com/pc/def/banner.p")
y = peakhell.load(x)
# Out:
# [[(' ', 95)],
#  [(' ', 14), ('#', 5), (' ', 70), ('#', 5), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 6),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 3),
#   ('#', 3),
#   (' ', 9),
#   ('#', 3),
#   (' ', 7),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 4),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 10),
#   ('#', 3),
#   (' ', 7),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 3),
#   ('#', 3),
#   (' ', 3),
#   ('#', 2),
#   (' ', 4),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
#   (' ', 5),
#   ('#', 2),
#   (' ', 2),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
# ...

# %%
import sys
for line in y:
    for char,times in line:
        sys.stdout.write(char*times)
    print('')
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
# ...
