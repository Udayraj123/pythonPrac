# %%
import re ,urllib, sys

#thisurl = "http://www.pythonchallenge.com/pc/def/linkedlist.php?nothing=44827"
thisurl = "http://www.pythonchallenge.com/pc/def/linkedlist.php?nothing=63579"

global counter
counter=139
def getID(thisurl):
    global counter
    handle = urllib.urlopen(thisurl)
    html_gunk =  re.search(r'[\d]+',handle.read())
    if html_gunk :
        counter+=1
        sys.stdout.write(str(counter))
        print(" > "+html_gunk.group())
        return getID("http://www.pythonchallenge.com/pc/def/linkedlist.php?nothing="+html_gunk.group())
    else :
        return thisurl
getID(thisurl)
# Out:
# 140 > 37278
# 141 > 53548
# 142 > 66081
# 143 > 67753
# 144 > 56337
# 145 > 3356
# 146 > 94525
# 147 > 89574
# 148 > 4413
# 149 > 82294
# 150 > 56060
# 151 > 95493
# 152 > 80865
# 153 > 66242
# 154 > 16065
# 155 > 62145
# 156 > 23147
# 157 > 83763
# 158 > 62381
# 159 > 76841
# 160 > 91706
# 161 > 9268
# 162 > 64814
# 163 > 80809
# 164 > 14039
# 165 > 73355
# 166 > 81905
# 167 > 36402
# 168 > 27221
# 169 > 79607
# 170 > 91763
# 171 > 11631
# 172 > 76396
# 173 > 69905
# 174 > 11073
# 175 > 71281
# 176 > 54345
# 177 > 19047
# 178 > 34376
# 179 > 3193
# 180 > 74258
# 181 > 62712
# 182 > 1823
# 183 > 21232
# 184 > 87890
# 185 > 21545
# 186 > 37136
# 187 > 23060
# 188 > 5385
# 189 > 4620
# 190 > 39111
# 191 > 35914
# 192 > 60310
# 193 > 19178
# 194 > 44671
# 195 > 45736
# 196 > 9216
# 197 > 12585
# 198 > 11302
# 199 > 33096
# 200 > 13967
# 201 > 57004
# 202 > 64196
# 203 > 73929
# 204 > 24800
# 205 > 25081
# 206 > 90033
# 207 > 45919
# 208 > 54827
# 209 > 73950
# 210 > 56978
# 211 > 8133
# ...

# %%
import pprint, pickle
import matplotlib.pyplot as plt

pkl_file = urllib.urlopen('http://www.pythonchallenge.com/pc/def/banner.p')
f= open('out.txt','w')
data1 = pickle.load(pkl_file)
# pprint.pprint(data1)
# graph=[]
# for i in range(0,23): graph.insert(i,len(data1[i])) ;plt.plot(graph);plt.show()
    # # data2 = pickle.load(f)
    
for dataArray in data1:
    for tup in dataArray:
        sys.stdout.write(tup[0]*tup[1])
    print('')
# f.close()
# # pprint.pprint(data2)
# f=open('out.txt')
# data1 = pickle.load(f)
# pprint.pprint(data1)
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
# ...

# %%
import zipfile
global kid
#global comment
kid ='90052'
comment=''
def fn(kid):
    f= open('./ch6/'+kid+'.txt')
    global comment
    content=f.read()
    #comment=comment + f.getinfo.comments()
    print(content)
    text_junk =  re.search(r'[\d]+',content)
    if(text_junk):
        fn(text_junk.group())
    else : print(kid)
        
fn(kid)
print("pras"[2])
# Out:
# Next nothing is 94191
# Next nothing is 85503
# Next nothing is 70877
# Next nothing is 15409
# Next nothing is 60838
# Next nothing is 80009
# Next nothing is 21347
# Next nothing is 24164
# Next nothing is 13836
# Next nothing is 80123
# Next nothing is 92453
# Next nothing is 69556
# Next nothing is 31491
# Next nothing is 13371
# Next nothing is 88143
# Next nothing is 82593
# Next nothing is 30645
# Next nothing is 88985
# Next nothing is 27190
# Next nothing is 24448
# Next nothing is 37468
# Next nothing is 49892
# Next nothing is 54714
# Next nothing is 75161
# Next nothing is 893
# Next nothing is 57882
# Next nothing is 40033
# Next nothing is 29521
# Next nothing is 5289
# Next nothing is 4701
# Next nothing is 32742
# Next nothing is 18751
# Next nothing is 68586
# Next nothing is 53984
# Next nothing is 52184
# Next nothing is 43807
# Next nothing is 56300
# Next nothing is 97649
# Next nothing is 88244
# Next nothing is 91669
# Next nothing is 88394
# ...

# %%
import bz2

code='BZh91AY&SYA\xaf\x82\r\x00\x00\x01\x01\x80\x02\xc0\x02\x00 \x00!\x9ah3M\x07<]\xc9\x14\xe1BA\x06\xbe\x084'
code2= 'BZh91AY&SY\x94$|\x0e\x00\x00\x00\x81\x00\x03$ \x00!\x9ah3M\x13<]\xc9\x14\xe1BBP\x91\xf08'
print(bz2.decompress(code).decode('utf-8'))
print(bz2.decompress(code2).decode('utf-8'))
# Out:
# huge
# file

# %%
curr="1"
def genterm(curr):
    nxt=""
    l=0
    while l<len(curr):
        i=1
        c=curr[l]
        while l<len(curr)-1:
            l=l+1;
            if(c==curr[l]):
                i+=1
            else :
                l=l-1
                break
        nxt+=str(i)+str(c)
        l=l+1
    return nxt
print (curr)
for i in range(0,30):
    curr=genterm(curr)
    print(len(curr))
    
    """
    x="1"
for each in range(30):
    x="".join([str(len(i+j))+i for i,j in re.findall(r"(\d)(\1*)", x)])
print len(x)
"""
# Out:
# 1
# 2
# 2
# 4
# 6
# 6
# 8
# 10
# 14
# 20
# 26
# 34
# 46
# 62
# 78
# 102
# 134
# 176
# 226
# 302
# 408
# 528
# 678
# 904
# 1182
# 1540
# 2012
# 2606
# 3410
# 4462
# 5808
